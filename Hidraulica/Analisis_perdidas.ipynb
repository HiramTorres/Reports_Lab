# %% [markdown]
# # Análisis de perdidas

# %% [markdown]
# ## Muestra para datos de 25% de velocidad

# %%
import pandas as pd 
import matplotlib.pyplot as plt 

id = pd.Series(range(1,9) , name="id")
df = pd.read_excel("PRACTICA.xlsx", sheet_name="25%")
df['id'] = id
df.set_index('id', inplace=True)
df
# Out:
#     Pump Speed n[rpm ]  Water Temperature T [°C]   Inlet Pressure Pin [KPa]  \
# id
# 1                  375                       25.6                       4.2
# 2                  375                       25.6                       4.1
# 3                  375                       25.7                       4.2
# 4                  375                       25.5                       4.1
# 5                  375                       25.5                       4.1
# 6                  375                       25.6                       4.1
# 7                  375                       25.5                       4.1
# 8                  375                       25.7                       4.1
#
#     Outlet Pressure Pout [KPa]  Motor torque t [Nm ]  Flow Rate Q [I/S]  \
# id
# 1                          5.2                  0.08               0.36
# 2                          5.1                  0.07               0.39
# ...

# %%
data25 = df[['Pump Speed n[rpm ]','Flow Rate Q [I/S]','Outlet Pressure Pout [KPa]', 'Outley Velocity Vout [m/s]','System Head Loss[m]']]
data25
# Out:
#     Pump Speed n[rpm ]  Flow Rate Q [I/S]  Outlet Pressure Pout [KPa]  \
# id
# 1                  375               0.36                         5.2
# 2                  375               0.39                         5.1
# 3                  375               0.39                         4.9
# 4                  375               0.40                         4.9
# 5                  375               0.41                         4.6
# 6                  375               0.40                         4.7
# 7                  375               0.40                         4.8
# 8                  375               0.40                         4.7
#
#     Outley Velocity Vout [m/s]  System Head Loss[m]
# id
# 1                        1.498                 0.64
# 2                        1.609                 0.74
# 3                        1.609                 0.74
# 4                        1.665                 0.79
# 5                        1.720                 0.84
# ...

# %%
Q25 = data25['Flow Rate Q [I/S]']
P_out25 = data25['Outlet Pressure Pout [KPa]']
plt.plot(Q,P_out, color = 'c')
plt.xlabel('Flow Rate')
plt.ylabel('Outlet Pressure')
plt.title('Pressure vs Flow Rate')
plt.show()

# %% [markdown]
# ## Muestra para datos de 50% de velocidad

# %%
id = pd.Series(range(1,9) , name="id")
df = pd.read_excel("PRACTICA.xlsx", sheet_name="50%")
df['id'] = id
df.set_index('id', inplace=True)
df
# Out:
#     Pump Speed n[rpm ]  Water Temperature T [°C]   Inlet Pressure Pin [KPa]  \
# id
# 1                  750                       25.7                       1.4
# 2                  750                       25.7                       1.6
# 3                  750                       25.7                       1.6
# 4                  750                       25.7                       1.5
# 5                  750                       25.7                       1.9
# 6                  750                       25.7                       2.2
# 7                  750                       25.7                       2.9
# 8                  750                       25.7                       3.5
#
#     Outlet Pressure Pout [KPa]  Motor torque t [Nm ]  Flow Rate Q [I/S]  \
# id
# 1                         10.0                  0.61               0.87
# 2                         10.6                  0.59               0.88
# ...

# %%
data50 = df[['Pump Speed n[rpm ]','Flow Rate Q [I/S]','Outlet Pressure Pout [KPa]', 'Outley Velocity Vout [m/s]','System Head Loss[m]']]
data50
# Out:
#     Pump Speed n[rpm ]  Flow Rate Q [I/S]  Outlet Pressure Pout [KPa]  \
# id
# 1                  750               0.87                        10.0
# 2                  750               0.88                        10.6
# 3                  750               0.85                        10.2
# 4                  750               0.85                        10.6
# 5                  750               0.84                        11.1
# 6                  750               0.80                        12.3
# 7                  750               0.69                        13.9
# 8                  750               0.57                        16.4
#
#     Outley Velocity Vout [m/s]  System Head Loss[m]
# id
# 1                        3.607                 3.64
# 2                        3.662                 3.76
# 3                        3.551                 3.53
# 4                        3.511                 3.53
# 5                        3.496                 3.42
# ...

# %%
Q50 = data50['Flow Rate Q [I/S]']
P_out50 = data50['Outlet Pressure Pout [KPa]']
plt.plot(Q,P_out, color = 'c')
plt.xlabel('Flow Rate')
plt.ylabel('Outlet Pressure')
plt.title('Pressure vs Flow Rate')
plt.show()

# %% [markdown]
# ## Muestra para datos de 75% de velocidad

# %%
id = pd.Series(range(1,9) , name="id")
df = pd.read_excel("PRACTICA.xlsx", sheet_name="75%")
df['id'] = id
df.set_index('id', inplace=True)
df
# Out:
#     Pump Speed n[rpm ]  Water Temperature T [°C]   Inlet Pressure Pin [KPa]  \
# id
# 1                 1125                       25.7                      -3.4
# 2                 1125                       25.7                      -3.3
# 3                 1125                       25.7                      -3.0
# 4                 1125                       25.6                      -2.3
# 5                 1125                       25.7                      -1.9
# 6                 1125                       25.6                      -1.4
# 7                 1125                       25.7                       0.0
# 8                 1125                       25.6                       1.6
#
#     Outlet Pressure Pout [KPa]  Motor torque t [Nm ]  Flow Rate Q [I/S]  \
# id
# 1                         18.7                  1.58               1.33
# 2                         19.2                  1.54               1.35
# ...

# %%
data75 = df[['Pump Speed n[rpm ]','Flow Rate Q [I/S]','Outlet Pressure Pout [KPa]', 'Outley Velocity Vout [m/s]','System Head Loss[m]']]
data75
# Out:
#     Pump Speed n[rpm ]  Flow Rate Q [I/S]  Outlet Pressure Pout [KPa]  \
# id
# 1                 1125               1.33                        18.7
# 2                 1125               1.35                        19.2
# 3                 1125               1.32                        19.8
# 4                 1125               1.28                        20.7
# 5                 1125               1.28                        22.5
# 6                 1125               1.25                        24.3
# 7                 1125               1.12                        28.2
# 8                 1125               1.01                        32.2
#
#     Outley Velocity Vout [m/s]  System Head Loss[m]
# id
# 1                       5.5490                 8.57
# 2                       5.6040                 8.74
# 3                       5.4930                 8.40
# 4                       5.3270                 1.90
# 5                       5.3327                 7.90
# ...

# %%
Q75 = data75['Flow Rate Q [I/S]']
P_out75 = data75['Outlet Pressure Pout [KPa]']
plt.plot(Q,P_out, color = 'c')
plt.xlabel('Flow Rate')
plt.ylabel('Outlet Pressure')
plt.title('Pressure vs Flow Rate')
plt.show()

# %% [markdown]
# ## Muestra para datos de 100% de velocidad

# %%
id = pd.Series(range(1,9) , name="id")
df = pd.read_excel("PRACTICA.xlsx", sheet_name="100%")
df['id'] = id
df.set_index('id', inplace=True)
df
# Out:
#     Pump Speed n[rpm ]  Water Temperature T [°C]   Inlet Pressure Pin [KPa]  \
# id
# 1                 1500                       25.5                      -9.6
# 2                 1500                       25.5                      -8.6
# 3                 1500                       25.5                      -8.3
# 4                 1500                       25.6                      -7.8
# 5                 1500                       25.6                      -6.3
# 6                 1500                       25.8                      -4.3
# 7                 1500                       25.8                      -1.2
# 8                 1500                       25.8                       2.1
#
#     Outlet Pressure Pout [KPa]  Motor torque t [Nm ]  Flow Rate Q [I/S]  \
# id
# 1                         30.4                  2.82               1.84
# 2                         31.9                  2.78               1.82
# ...

# %%
data100 = df[['Pump Speed n[rpm ]','Outlet Pressure Pout [KPa]', 'Outley Velocity Vout [m/s]','System Head Loss[m]','Flow Rate Q [I/S]']]
data100
# Out:
#     Pump Speed n[rpm ]  Outlet Pressure Pout [KPa]  \
# id
# 1                 1500                        30.4
# 2                 1500                        31.9
# 3                 1500                        34.4
# 4                 1500                        36.8
# 5                 1500                        40.9
# 6                 1500                        48.0
# 7                 1500                        56.9
# 8                 1500                        61.2
#
#     Outley Velocity Vout [m/s]  System Head Loss[m]  Flow Rate Q [I/S]
# id
# 1                        7.657                16.24               1.84
# 2                        7.546                15.77               1.82
# 3                        7.269                14.64               1.75
# 4                        7.047                13.37               1.69
# 5                        6.659                12.30               1.60
# ...

# %%
Q100 = data100['Flow Rate Q [I/S]']
P_out100 = data100['Outlet Pressure Pout [KPa]']
plt.plot(Q100, P_out100, color='c')
plt.xlabel('Flow Rate Q [I/S]')
plt.ylabel('Outlet Pressure Pout [KPa]')
plt.title('Flow Rate  vs Outlet Pressure')
plt.show()
