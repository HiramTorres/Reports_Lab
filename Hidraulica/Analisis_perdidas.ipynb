# %% [markdown]
# # Análisis de perdidas

# %% [markdown]
# ## Muestra para datos de 25% de velocidad

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_theme(style="darkgrid")

id = pd.Series(range(1,9) , name="id")
df25 = pd.read_excel("PRACTICA.xlsx", sheet_name="25%")
df50 = pd.read_excel("PRACTICA.xlsx", sheet_name="50%")
df75 = pd.read_excel("PRACTICA.xlsx", sheet_name="75%")
df100 = pd.read_excel("PRACTICA.xlsx", sheet_name="100%")

df25['id'] = id
df25.set_index('id', inplace=True)
df25
# Out:
#     Pump Speed n[rpm ]  Water Temperature T [°C]   Inlet Pressure Pin [KPa]  \
# id
# 1                  375                       25.6                       4.2
# 2                  375                       25.6                       4.1
# 3                  375                       25.7                       4.2
# 4                  375                       25.5                       4.1
# 5                  375                       25.5                       4.1
# 6                  375                       25.6                       4.1
# 7                  375                       25.5                       4.1
# 8                  375                       25.7                       4.1
#
#     Outlet Pressure Pout [KPa]  Motor torque t [Nm ]  Flow Rate Q [I/S]  \
# id
# 1                          5.2                  0.08               0.36
# 2                          5.1                  0.07               0.39
# 3                          4.9                  0.06               0.39
# 4                          4.9                  0.05               0.40
# 5                          4.6                  0.05               0.41
# 6                          4.7                  0.06               0.40
# 7                          4.8                  0.05               0.40
# 8                          4.7                  0.06               0.40
#
#     Density of water [Kg/m^3]  Inlet Velocity Vin [m/s]  \
# id
# 1                         997                     0.831
# 2                         997                     0.892
# 3                         997                     0.892
# 4                         997                     0.923
# 5                         997                     0.954
# 6                         997                     0.954
# 7                         997                     0.923
# 8                         997                     0.923
#
#     Outley Velocity Vout [m/s]  Static Head Hs[m]  ...  \
# id                                                 ...
# 1                        1.498              0.096  ...
# 2                        1.609              0.096  ...
# 3                        1.609              0.072  ...
# 4                        1.665              0.083  ...
# 5                        1.720              0.057  ...
# 6                        1.720              0.065  ...
# 7                        1.665              0.077  ...
# 8                        1.665              0.059  ...
#
#     Predicted Flow Rate [I/s]  Predicted Total Head[m]  \
# id
# 1                        0.24                    0.111
# 2                        0.26                    0.116
# 3                        0.26                    0.106
# 4                        0.27                    0.114
# 5                        0.28                    0.105
# 6                        0.28                    0.108
# 7                        0.27                    0.111
# 8                        0.27                    0.103
#
#     Vapour Pressure Pv[Kpa]  Net+Ve Suction Head Available[m]  \
# id
# 1                      3.26                             10.37
# 2                      3.26                             10.38
# 3                    328.00                             10.38
# 4                      3.24                             10.38
# 5                      3.24                             10.38
# 6                      3.26                             10.38
# 7                      3.24                             10.38
# 8                      3.27                             10.38
#
#     Pipe Length [m]  Pipe Diameter d [m]  Coefficient kn[-]  Coeciffient C[-]  \
# id
# 1             0.916                    0                4.9                 0
# 2             0.916                    0                4.9                 0
# 3             0.916                    0                4.9                 0
# 4             0.916                    0                4.9                 0
# 5             0.916                    0                4.9                 0
# 6             0.916                    0                4.9                 0
# 7             0.916                    0                4.9                 0
# 8             0.916                    0                4.9                 0
#
#     System Head Loss[m]  Walkthrough Questions Score [%]
# id
# 1                  0.64                                0
# 2                  0.74                                0
# 3                  0.74                                0
# 4                  0.79                                0
# 5                  0.84                                0
# 6                  0.84                                0
# 7                  0.79                                0
# 8                  0.79                                0
#
# [8 rows x 25 columns]

# %%
data25 = df25[['Pump Speed n[rpm ]','Flow Rate Q [I/S]','Outlet Pressure Pout [KPa]', 'Outley Velocity Vout [m/s]','System Head Loss[m]']]
data25
# Out:
#     Pump Speed n[rpm ]  Flow Rate Q [I/S]  Outlet Pressure Pout [KPa]  \
# id
# 1                  375               0.36                         5.2
# 2                  375               0.39                         5.1
# 3                  375               0.39                         4.9
# 4                  375               0.40                         4.9
# 5                  375               0.41                         4.6
# 6                  375               0.40                         4.7
# 7                  375               0.40                         4.8
# 8                  375               0.40                         4.7
#
#     Outley Velocity Vout [m/s]  System Head Loss[m]
# id
# 1                        1.498                 0.64
# 2                        1.609                 0.74
# 3                        1.609                 0.74
# 4                        1.665                 0.79
# 5                        1.720                 0.84
# 6                        1.720                 0.84
# 7                        1.665                 0.79
# 8                        1.665                 0.79

# %%
Q25 = data25['Flow Rate Q [I/S]']
P_out25 = data25['Outlet Pressure Pout [KPa]']
plt.plot(Q25,P_out25, color = 'c')
plt.xlabel('Flow Rate')
plt.ylabel('Outlet Pressure')
plt.title('Pressure vs Flow Rate')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Muestra para datos de 50% de velocidad

# %%
df50['id'] = id
df50.set_index('id', inplace=True)
data50 = df50[['Pump Speed n[rpm ]','Flow Rate Q [I/S]','Outlet Pressure Pout [KPa]', 'Outley Velocity Vout [m/s]','System Head Loss[m]']]
data50
# Out:
#     Pump Speed n[rpm ]  Flow Rate Q [I/S]  Outlet Pressure Pout [KPa]  \
# id
# 1                  750               0.87                        10.0
# 2                  750               0.88                        10.6
# 3                  750               0.85                        10.2
# 4                  750               0.85                        10.6
# 5                  750               0.84                        11.1
# 6                  750               0.80                        12.3
# 7                  750               0.69                        13.9
# 8                  750               0.57                        16.4
#
#     Outley Velocity Vout [m/s]  System Head Loss[m]
# id
# 1                        3.607                 3.64
# 2                        3.662                 3.76
# 3                        3.551                 3.53
# 4                        3.511                 3.53
# 5                        3.496                 3.42
# 6                        3.329                 3.11
# 7                        2.885                 2.34
# 8                        2.386                 1.61

# %%
Q50 = data50['Flow Rate Q [I/S]']
P_out50 = data50['Outlet Pressure Pout [KPa]']
plt.plot(Q50,P_out50, color = 'c')
plt.xlabel('Flow Rate')
plt.ylabel('Outlet Pressure')
plt.title('Pressure vs Flow Rate')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Muestra para datos de 75% de velocidad

# %%
df75['id'] = id
df75.set_index('id', inplace=True)
data75 = df75[['Pump Speed n[rpm ]','Flow Rate Q [I/S]','Outlet Pressure Pout [KPa]', 'Outley Velocity Vout [m/s]','System Head Loss[m]']]
data75
# Out:
#     Pump Speed n[rpm ]  Flow Rate Q [I/S]  Outlet Pressure Pout [KPa]  \
# id
# 1                 1125               1.33                        18.7
# 2                 1125               1.35                        19.2
# 3                 1125               1.32                        19.8
# 4                 1125               1.28                        20.7
# 5                 1125               1.28                        22.5
# 6                 1125               1.25                        24.3
# 7                 1125               1.12                        28.2
# 8                 1125               1.01                        32.2
#
#     Outley Velocity Vout [m/s]  System Head Loss[m]
# id
# 1                       5.5490                 8.57
# 2                       5.6040                 8.74
# 3                       5.4930                 8.40
# 4                       5.3270                 1.90
# 5                       5.3327                 7.90
# 6                       5.2160                 7.58
# 7                       4.6610                 6.06
# 8                       4.2170                 4.97

# %%
Q75 = data75['Flow Rate Q [I/S]']
P_out75 = data75['Outlet Pressure Pout [KPa]']
plt.plot(Q75,P_out75, color = 'c')
plt.xlabel('Flow Rate')
plt.ylabel('Outlet Pressure')
plt.title('Pressure vs Flow Rate')
plt.show()

# %% [markdown]
# ## Muestra para datos de 100% de velocidad

# %%
df100['id'] = id
df100.set_index('id', inplace=True)
data100 = df100[['Pump Speed n[rpm ]','Outlet Pressure Pout [KPa]', 'Outley Velocity Vout [m/s]','System Head Loss[m]','Flow Rate Q [I/S]']]
data100
# Out:
#     Pump Speed n[rpm ]  Outlet Pressure Pout [KPa]  \
# id
# 1                 1500                        30.4
# 2                 1500                        31.9
# 3                 1500                        34.4
# 4                 1500                        36.8
# 5                 1500                        40.9
# 6                 1500                        48.0
# 7                 1500                        56.9
# 8                 1500                        61.2
#
#     Outley Velocity Vout [m/s]  System Head Loss[m]  Flow Rate Q [I/S]
# id
# 1                        7.657                16.24               1.84
# 2                        7.546                15.77               1.82
# 3                        7.269                14.64               1.75
# 4                        7.047                13.37               1.69
# 5                        6.659                12.30               1.60
# 6                        6.159                10.54               1.48
# 7                        5.826                 9.44               1.40
# 8                        3.829                 9.30               0.92

# %%
Q100 = data100['Flow Rate Q [I/S]']
P_out100 = data100['Outlet Pressure Pout [KPa]']
Loss_100 = data100['System Head Loss[m]']

plt.plot(Q100, P_out100, "-",color='c', label='Outlet Pressure')
plt.plot(Q100, Loss_100, "-",color='r', label='System Head Loss')
plt.xlabel('Flow Rate Q [I/S]')
plt.title('Flow Rate  vs Outlet Pressure')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(1,2, sharey = True)
ax[0].plot(Q100,P_out100,color = 'c')
ax[0].set_xlabel('Flow Rate Q [I/S]')
ax[0].set_ylabel('Outlet Pressure Pout [KPa]')
ax[0].set_title('Flow Rate  vs Outlet Pressure')
ax[1].plot(Q100,Loss_100,color = 'r')
ax[1].set_xlabel('Flow Rate Q [I/S]')
ax[1].set_ylabel('System Head Loss[m]')
ax[1].set_title('Flow Rate  vs System Head Loss')
plt.show()
