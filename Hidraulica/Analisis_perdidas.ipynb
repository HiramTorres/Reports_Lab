# %% [markdown]
# ## Muestra para datos de 25% de velocidad  (375 rpm)

# %% [markdown]
# # Análisis de perdidas

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_theme(style="darkgrid")

id = pd.Series(range(1,9) , name="id")
df25 = pd.read_excel("PRACTICA.xlsx", sheet_name="25%")
df50 = pd.read_excel("PRACTICA.xlsx", sheet_name="50%")
df75 = pd.read_excel("PRACTICA.xlsx", sheet_name="75%")
df100 = pd.read_excel("PRACTICA.xlsx", sheet_name="100%")

df25['id'] = id
df25.set_index('id', inplace=True)
data25 = df25[['Pump Speed n[rpm ]','Flow Rate Q [I/S]','Outlet Pressure Pout [KPa]', 'Outley Velocity Vout [m/s]','System Head Loss[m]']]
data25
# Out:
#     Pump Speed n[rpm ]  Flow Rate Q [I/S]  Outlet Pressure Pout [KPa]  \
# id
# 1                  375               0.36                         5.2
# 2                  375               0.39                         5.1
# 3                  375               0.39                         4.9
# 4                  375               0.40                         4.9
# 5                  375               0.41                         4.6
# 6                  375               0.40                         4.7
# 7                  375               0.40                         4.8
# 8                  375               0.40                         4.7
#
#     Outley Velocity Vout [m/s]  System Head Loss[m]
# id
# 1                        1.498                 0.64
# 2                        1.609                 0.74
# 3                        1.609                 0.74
# 4                        1.665                 0.79
# 5                        1.720                 0.84
# ...

# %%
Q25 = data25['Flow Rate Q [I/S]']
P_out25 = data25['Outlet Pressure Pout [KPa]']
Vel25 = data25['Outley Velocity Vout [m/s]']
HLoss25 = data25['System Head Loss[m]']

fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].plot(Q25, P_out25, color='c')
ax[0].set_xlabel('Flow Rate [I/S]')
ax[0].set_ylabel('Pressure out [KPa]')

ax[1].plot(Q25, Vel25, color = 'r')
ax[1].set_xlabel('Flow Rate [I/S]')
ax[1].set_ylabel('Velocity [m/s]')

ax[2].plot(Q25, HLoss25, color = 'b')
ax[2].set_xlabel('Flow Rate [I/S]')
ax[2].set_ylabel('Head Loss [m]')

plt.savefig('Graf25%.png')
plt.show()

# %%
plt.plot(Q25,P_out25, color = 'c')
plt.plot(Q25,Vel25, color = 'r')
plt.plot(Q25,HLoss25, color = 'b')
plt.xlabel('Flow Rate')
plt.legend(['Pressure', 'Velocity', 'Head Loss'])

plt.savefig('AllGraf25%.png')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Muestra para datos de 50% de velocidad (750 rpm)

# %%
df50['id'] = id
df50.set_index('id', inplace=True)
data50 = df50[['Pump Speed n[rpm ]','Flow Rate Q [I/S]','Outlet Pressure Pout [KPa]', 'Outley Velocity Vout [m/s]','System Head Loss[m]']]
data50
# Out:
#     Pump Speed n[rpm ]  Flow Rate Q [I/S]  Outlet Pressure Pout [KPa]  \
# id
# 1                  750               0.87                        10.0
# 2                  750               0.88                        10.6
# 3                  750               0.85                        10.2
# 4                  750               0.85                        10.6
# 5                  750               0.84                        11.1
# 6                  750               0.80                        12.3
# 7                  750               0.69                        13.9
# 8                  750               0.57                        16.4
#
#     Outley Velocity Vout [m/s]  System Head Loss[m]
# id
# 1                        3.607                 3.64
# 2                        3.662                 3.76
# 3                        3.551                 3.53
# 4                        3.511                 3.53
# 5                        3.496                 3.42
# ...

# %%
Q50 = data50['Flow Rate Q [I/S]']
P_out50 = data50['Outlet Pressure Pout [KPa]']
Vel50 = data50['Outley Velocity Vout [m/s]']
HLoss50 = data50['System Head Loss[m]']

fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].plot(Q50, P_out50, color='c')
ax[0].set_xlabel('Flow Rate [I/S]')
ax[0].set_ylabel('Pressure out [KPa]')

ax[1].plot(Q50, Vel50, color = 'r')
ax[1].set_xlabel('Flow Rate [I/S]')
ax[1].set_ylabel('Velocity [m/s]')

ax[2].plot(Q50, HLoss50, color = 'b')
ax[2].set_xlabel('Flow Rate [I/S]')
ax[2].set_ylabel('Head Loss [m]')

plt.savefig('Graf50%.png')
plt.show()

# %%
plt.plot(Q50,P_out50, color = 'c')
plt.plot(Q50,Vel50, color = 'r')
plt.plot(Q50,HLoss50, color = 'b')
plt.xlabel('Flow Rate')
plt.legend(['Pressure', 'Velocity', 'Head Loss'])

plt.savefig('AllGraf50%.png')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Muestra para datos de 75% de velocidad (1125 rpm)

# %%
df75['id'] = id
df75.set_index('id', inplace=True)
data75 = df75[['Pump Speed n[rpm ]','Flow Rate Q [I/S]','Outlet Pressure Pout [KPa]', 'Outley Velocity Vout [m/s]','System Head Loss[m]']]
data75
# Out:
#     Pump Speed n[rpm ]  Flow Rate Q [I/S]  Outlet Pressure Pout [KPa]  \
# id
# 1                 1125               1.33                        18.7
# 2                 1125               1.35                        19.2
# 3                 1125               1.32                        19.8
# 4                 1125               1.28                        20.7
# 5                 1125               1.28                        22.5
# 6                 1125               1.25                        24.3
# 7                 1125               1.12                        28.2
# 8                 1125               1.01                        32.2
#
#     Outley Velocity Vout [m/s]  System Head Loss[m]
# id
# 1                       5.5490                 8.57
# 2                       5.6040                 8.74
# 3                       5.4930                 8.40
# 4                       5.3270                 1.90
# 5                       5.3327                 7.90
# ...

# %%
Q75 = data75['Flow Rate Q [I/S]']
P_out75 = data75['Outlet Pressure Pout [KPa]']
Vel75 = data75['Outley Velocity Vout [m/s]']
HLoss75 = data75['System Head Loss[m]']

fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].plot(Q75, P_out75, color='c')
ax[0].set_xlabel('Flow Rate [I/S]')
ax[0].set_ylabel('Pressure out [KPa]')

ax[1].plot(Q75, Vel75, color = 'r')
ax[1].set_xlabel('Flow Rate [I/S]')
ax[1].set_ylabel('Velocity [m/s]')

ax[2].plot(Q75, HLoss75, color = 'b')
ax[2].set_xlabel('Flow Rate [I/S]')
ax[2].set_ylabel('Head Loss [m]')

plt.savefig('Graf75%.png')
plt.show()

# %%
plt.plot(Q75,P_out75, color = 'c')
plt.plot(Q75,Vel75, color = 'r')
plt.plot(Q75,HLoss75, color = 'b')
plt.xlabel('Flow Rate')
plt.legend(['Pressure', 'Velocity', 'Head Loss'])

plt.savefig('AllGraf75%.png')
plt.show()

# %% [markdown]
# ## Muestra para datos de 100% de velocidad (1500 rpm)

# %%
df100['id'] = id
df100.set_index('id', inplace=True)
data100 = df100[['Pump Speed n[rpm ]','Outlet Pressure Pout [KPa]', 'Outley Velocity Vout [m/s]','System Head Loss[m]','Flow Rate Q [I/S]']]
data100
# Out:
#     Pump Speed n[rpm ]  Outlet Pressure Pout [KPa]  \
# id
# 1                 1500                        30.4
# 2                 1500                        31.9
# 3                 1500                        34.4
# 4                 1500                        36.8
# 5                 1500                        40.9
# 6                 1500                        48.0
# 7                 1500                        56.9
# 8                 1500                        61.2
#
#     Outley Velocity Vout [m/s]  System Head Loss[m]  Flow Rate Q [I/S]
# id
# 1                        7.657                16.24               1.84
# 2                        7.546                15.77               1.82
# 3                        7.269                14.64               1.75
# 4                        7.047                13.37               1.69
# 5                        6.659                12.30               1.60
# ...

# %%
Q100 = data100['Flow Rate Q [I/S]']
P_out100 = data100['Outlet Pressure Pout [KPa]']
Vel100 = data100['Outley Velocity Vout [m/s]']
HLoss100 = data100['System Head Loss[m]']

fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].plot(Q100, P_out100, color='c')
ax[0].set_xlabel('Flow Rate [I/S]')
ax[0].set_ylabel('Pressure out [KPa]')

ax[1].plot(Q100, Vel100, color = 'r')
ax[1].set_xlabel('Flow Rate [I/S]')
ax[1].set_ylabel('Velocity [m/s]')

ax[2].plot(Q100, HLoss100, color = 'b')
ax[2].set_xlabel('Flow Rate [I/S]')
ax[2].set_ylabel('Head Loss [m]')

plt.savefig('Graf100%.png')
plt.show()

# %%
plt.plot(Q100,P_out100, color = 'c')
plt.plot(Q100,Vel100, color = 'r')
plt.plot(Q100,HLoss100, color = 'b')
plt.xlabel('Flow Rate')
plt.legend(['Pressure', 'Velocity', 'Head Loss'])

plt.savefig('AllGraf100%.png')
plt.show()
