# %% [markdown]
# # Análisis de datos para un caudal de 100%

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# Read the data 

data100 = pd.read_excel('Datos Turbina Francis.xlsx', sheet_name='100')
data75 = pd.read_excel("Datos Turbina Francis.xlsx", sheet_name= '75')
data50 = pd.read_excel("Datos Turbina Francis.xlsx", sheet_name= '50')

id = pd.Series(range(1,4), name = 'id')
data100["id"] = id
data100.set_index('id', inplace=True)

data75["id"] = id
data75.set_index('id', inplace=True)

data50["id"] = id
data50.set_index('id', inplace=True)

data100
# Out:
#     Apertura  v (rpm)  F (N)
# id
# 1        100     1009    5.2
# 2         50     1084    6.0
# 3         25     1155    6.4

# %%
A_out100 = data100['Apertura']
Rev100 = data100['v (rpm)']
Force100  = data100['F (N)'] 

fig, ax = plt.subplots(1,3, figsize=(15,5))

ax[0].plot(Rev100, Force100, color = 'c')
ax[0].set_xlabel('Revoluciones por minuto')
ax[0].set_ylabel('Fuerza (N)')

ax[1].plot(Rev100, A_out100, color = 'r')
ax[1].set_xlabel('Revoluciones por minuto')
ax[1].set_ylabel('apertura salida')

ax[2].plot(A_out100,Force100, color = 'b')
ax[2].set_xlabel('Apertura de salida')
ax[2].set_ylabel('Fuerza (N)')

plt.savefig('fig1')
plt.show()

# %% [markdown]
# # Análisis de datos para un caudal de 75%

# %%
A_out75 = data75['Apertura']
Rev75 = data75['v (rpm)']
Force75  = data75['F (N)'] 

fig, ax = plt.subplots(1,3, figsize=(15,5))

ax[0].plot(Rev75, Force75, color = 'c')
ax[0].set_xlabel('Revoluciones por minuto')
ax[0].set_ylabel('Fuerza (N)')

ax[1].plot(Rev75, A_out75, color = 'r')
ax[1].set_xlabel('Revoluciones por minuto')
ax[1].set_ylabel('apertura salida')

ax[2].plot(A_out75,Force75, color = 'b')
ax[2].set_xlabel('Apertura de salida')
ax[2].set_ylabel('Fuerza (N)')

plt.savefig('fig2')
plt.show()

# %% [markdown]
# # Análisis de datos para un caudal de 50%

# %%
A_out50 = data50['Apertura']
Rev50 = data50['v (rpm)']
Force50  = data50['F (N)'] 

fig, ax = plt.subplots(1,3, figsize=(15,5))

ax[0].plot(Rev50, Force50, color = 'c')
ax[0].set_xlabel('Revoluciones por minuto')
ax[0].set_ylabel('Fuerza (N)')

ax[1].plot(Rev50, A_out50, color = 'r')
ax[1].set_xlabel('Revoluciones por minuto')
ax[1].set_ylabel('apertura salida')

ax[2].plot(A_out50,Force50, color = 'b')
ax[2].set_xlabel('Apertura de salida')
ax[2].set_ylabel('Fuerza (N)')

plt.savefig('fig3')
plt.show()
